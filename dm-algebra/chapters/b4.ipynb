# %% [markdown]
# ## 1. 散点图绘制
#
# 基础的用法是传2个 数组, `f(x) = x` 的格式

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.scatter(x_values, y_values)

# optional save to figures
plt.savefig('figures/B.1.svg')

# %%
# marker 和 c 用来自定义 散点图 的外观
plt.scatter(x_values, y_values, marker='x', c='red')
plt.savefig('figures/B.2.svg')

# %% [markdown]
# ## 2. 折线图
#
# 先来1个2点间的折线图

# %%
def plot_segment(p1, p2):
    """
    元组 -> 列表
    """
    x1, y1 = p1
    x2, y2 = p2
    plt.plot([x1, x2], [y1, y2], marker='o')


point1 = (0, 3)
point2 = (2, 1)
plot_segment(point1, point2)
plt.savefig('figures/B.4.svg')

# %% [markdown]
# 直线肯定是包含无限点的 .
#
# 我们可以可以传1个区间和函数进去 .
#
# f(x) = x
#
# 下面画了 1个三角函数

# %%
import numpy as np

x_values = np.arange(0, 10, 0.01)
y_values = np.sin(x_values)

# plot
plt.plot(x_values, y_values)
plt.savefig('figures/B.5.svg')
